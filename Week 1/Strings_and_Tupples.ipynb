# %%
#Date :09-02-2023

STRINGS

It is a sequence of characters. 

Raw input numbers must be converted to String
We can index with string

You will get a python error if you attempt to index beyond end of a string

Strings have length (len) functions. a functon is a some stored code that we use.

it usually start from 0.

LOOPING THROUGH STRINGS

Use a while statetement and an iteration function we can construct a loop to look at each

A definite loop (for ) cn be used

e.g
fruit = 'banana'
for letter in fruit :
print(letter)

E.g to count number of time an item is repeated

word = 'banana'
count = 0
for letter in word:
if letter == 'a'
count = count=1
 print count

In the above the iteration variable iterates through the string and the block body of code is executed once each value in the sequence.


SLICING STRINGS

We can also look at any continous section of a string using a 'colon operator'

The second number is one beyond the end of the slice-up to but not including

if the 2nd no is beyond the end of d string, it stops at the end

E.G
Monty Python
01234567891011

s = 'Monty Python'
 print(s[0:4])
 Mont
 print(s[6:7])
 P
   print(s[6:20])
   Python
   
   If we eliminate the begining it assume it to be the 1st of the string and end to be last. 
   e.g (s[ :2])
   
   or (s[3: ]
   
   
   
  CHAPTER 8: PYTHON LIST
  
  Algorithims: A set of rules to solve a problem
  
  Data Structures: A particular way of organizing data in a computer
  
 Most of our variables have one value in them when we put a new value in the variable, the old value is overwritten
 
 
 A list is a kind of Colection od data. it can hold values of multiple data types
 
 
                                                                                                                                                                                                    
 
 A colecting allows us to put a value in single valuable, it makes it easy to carr all or many valuesaround in one convenient package
 
 e.g
 
 friends = ('Joseph' , 'Glenn' , 'Sally')
 carryon = ('socks' , 'shirts' , 'perfume')
   
   LIST Constants are surrounded by square brackets [] and elemnts inside it a separated by commas
   
   a list element can be any python object-even
   
   N.B Python has no recognition for singular nor plurals.
   
   LOOKING INSIDE LISTS
   It can be changed(mutable)
   Strings are immutable, we can only make a new string
   
   
   CONCATENATING LISTS USING +
   We can create a new list by adding two existing lists togeether
    e.g
    a= (1,2,3)
    b =(4,5,6)
    c= a + b
     print c
     (1,2,3,4,5,6)
     print (a)
     1,2,3
     
     
     Lists can be sliced using
     
     
     LIST METHODS
     
     append, count, extend, index,insert, pop,remove,sort
     
     Building lists from scratch
     we can create an empty list and then add elements using append method
     
     the list statys in order and new elements are added at the end of the list
     
     e.g
     stuff = list()
     stuff.append('book')
     stuff.append(99)
     print(stuff)
     ('book',''99)
     stuff.append('cookie')
     print(stuff)
      ('book', 99, 'cookie')
     
     Is Something in a list?
     
      Python provides two operators that let you check if an item is in a list
      
      They are logical operators that return True of False
      They do not modify the list
      E.g
      
        some = (1,9,21,10,16)
        9 in some
      True
      15 in some
      False
      20 not in some
      True
      
    
     
lists are inorder

A lsit can hold many items keeps those items in the order until we do something to change the order

a list can be sorted i.e change its order
The sort methos (unlke in strings) means 'sort yourself'

Methods in Lists

insert e.g num.insert(5,'Go')
remove e.g (num.remove('Go')
,extend
len e.g len(x)

min e.g min(x)
sum e.g sum(x)
sum(x)/len(x)


TUPPLES they are immutable smilr to string.
u can traceback in tupples
they re more efficient
better memory use
high performnace
Tupples are comparable
