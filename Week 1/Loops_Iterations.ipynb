# %%
#LOOPS AND ITERATION

# %%
n = 5
while n > 0:
    print(n)
    n = n-1
    print('Blastoff')
    print(n)
# Out:
# 5
# Blastoff
# 4
# 4
# Blastoff
# 3
# 3
# Blastoff
# 2
# 2
# Blastoff
# 1
# 1
# Blastoff
# 0

# %%
#Infinite loop

# %%
#n = 5
#while n > 0:
  #print('team')
  #print('lean')
    #Break
    
#print('dry off')

# %%
#DEFINITE LOOPS e.g for loop

# %%
friends = ('Joy', 'Juli', 'Jane')
for friend in friends:
    print('Happy new year:', friend)
    print('Done')
# Out:
# Happy new year: Joy
# Done
# Happy new year: Juli
# Done
# Happy new year: Jane
# Done

# %%
names = ('Jamiu','Olabisi','Omotoso')
for name in names:
    print(name,'_is_the best name:')
    print('Yes!')
# Out:
# Jamiu _is_the best name:
# Yes!
# Olabisi _is_the best name:
# Yes!
# Omotoso _is_the best name:
# Yes!

# %%
#IS and ISNOT

#Dont use is for Integers, Float and Strings, use it for Booleans

# %%
#FOR LOOP
#Iterates through a sequence of range of numbers generated by the function.
#copy file
#process d copied files and install software

#use for loop when:there is a sequence of action u want to iterate
#use while loop when u want to repeat an action until a condition changes
#to specify the ranges not starting with 0
#e.g 
product = 1
for n in range(1,10):
 product = product * n
print(product)
# Out:
# 362880

# %%
def to_celsius(x):
    return (x-32)*5/9


for x in range (0,101,10):
    print(x, to_celsius(x))
# Out:
# 0 -17.77777777777778
# 10 -12.222222222222221
# 20 -6.666666666666667
# 30 -1.1111111111111112
# 40 4.444444444444445
# 50 10.0
# 60 15.555555555555555
# 70 21.11111111111111
# 80 26.666666666666668
# 90 32.22222222222222
# 100 37.77777777777778

# %%
#Exercise 1: Write a program to print n natural number in descending order using a while
#loop.

n = 10
while n > 0:
print(n)
n = n-1
print('Done')
# Out:
#   File "C:\Users\hp\AppData\Local\Temp\ipykernel_5108\1213816236.py", line 6
#     print(n)
#     ^
# IndentationError: expected an indented block
