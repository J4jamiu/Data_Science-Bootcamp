# %%
INTRODUCTION TO DATA VISUALIZATION IN PYTHON

# %%
import matplotlib as npi

# %%
#matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [0,1,2,3,4,5]
y = [0,2,4,6,8,10]
#plt.plot(x,y,label= '2x', color='red', linewidth=2,linestyle='--', marker='.',markersize=18, markeredgecolor='black')
#You can use above or below
plt.plot(x,y, 'g^--', label='2x')
plt.title('My Second Graph', fontdict={'fontname': 'Comic Sans MS','fontsize':20} ) 
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.show()

# %%
##REAL WORLD EXAMPLES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#IMPORT THE DATA SAVED IN : C:\Users\user\Desktop\DATA SCIENCE BOOTCAMP\Excercise

# %%
gas = pd.read_csv('./Excercise\gas_prices.csv')
plt.title('Gas Prices Comparism in Different Countries (in USD)', fontdict={'fontweight':'bold', 'fontsize': 13})
plt.plot(gas.Year, gas.USA,'r.--', label= 'United States of America')
plt.plot(gas.Year, gas.Canada,'g.--', label = 'Canada')
plt.plot(gas['Year'], gas['South Korea'],'b.--', label= 'South Korea')
plt.plot(gas.Year,gas.Australia, 'b--', label= 'Australia')
#ANOTHER METTHOD OF PLOTTING IT
#countries_to_look_at =['Canada','USA','South Korea','Australia']
#for country in gas:
 #   if country in countries_to_look_at:
  #          plt.plot(gas.Year,gas[country], marker='.')
#print(gas.Year[::3])
            
plt.xticks(gas.Year[::3])
plt.xlabel('Year')
plt.ylabel('US Dollars')
plt.legend()
plt.savefig('Gas_price_figure.png', dpi=300)
plt.show()
